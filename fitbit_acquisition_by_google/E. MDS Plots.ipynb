# %%
import re
import pandas as pd
import datetime as dt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount= True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
df_tweets = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Text Analytics/Project/Clean_MDS_Tweets.csv')
df_tweets['text'] = df_tweets['text'].fillna('NA')
df_tweets.shape
# Out:
# (50855, 3)

# %%
df_tweets.head(5)
# Out:
#           timestamp  ...        date
# 0  10/27/2019 23:59  ...  10/27/2019
# 1  10/27/2019 23:59  ...  10/27/2019
# 2  10/27/2019 23:49  ...  10/27/2019
# 3  10/27/2019 23:43  ...  10/27/2019
# 4  10/27/2019 23:42  ...  10/27/2019
#
# [5 rows x 3 columns]

# %%
# import spacy
# from spacy import displacy
# from collections import Counter
# import en_core_web_sm
# nlp = en_core_web_sm.load()

# %%
# doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
# print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'), ('Google', 'ORG'), ('$5.1 billion', 'MONEY'), ('Wednesday', 'DATE')]

# %%
# #https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da

# def getentities(s):
#   doc = nlp(s)
#   lst = [(X.text, X.label_) for X in doc.ents]
#   entity= []
#   for i in lst:
#     if i[1] == 'ORG':
#       entity.append(i[0])
#   return entity


# df_tweets['entities'] = df_tweets['text'].map(getentities)

# %%
# df_tweets['entities'].head(5)
# Out:
# 0                                                []
# 1                                         [POLLIX®]
# 2    [Fii iFever Bluetooth Intelligent Thermometer]
# 3                                        [Triangle]
# 4                                             [EMA]
# Name: entities, dtype: object

# %%
# entities_recognized = list(set(df_tweets['entities'].sum()))

# %%
# wordcounts = pd.Series(df_tweets['entities'].sum()).value_counts()
# wordfrequency = pd.DataFrame(wordcounts)
# wordfrequency.reset_index(inplace= True)
# wordfrequency.columns = ["Entities","Count"]
# wordfrequency.head(5)
# Out:
#       Entities  Count
# 0       Google   5270
# 1       Fitbit   3315
# 2        Apple   2149
# 3  Apple Watch   1005
# 4      Android    624

# %%
# wordfrequency.to_csv('/content/gdrive/My Drive/Colab Notebooks/Text Analytics/Project/Entities_frequency.csv')

# %%
df_tweets.shape
# Out:
# (50855, 3)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
cleaned_desc = []

cntr = 0



for i in range(len(df_tweets)):
  cntr = cntr+1
  if cntr == 5000:
    print('Number of rows read until now:',i+1)
    cntr = 0

  try:
    new_words = []
    body = df_tweets['text'][i]
    words = word_tokenize(body)
    for w in words:
      w = w.lstrip().rstrip().lower()
      new_words.append(w)
#    words = w.lstrip().rstrip().lower()
    filtered_words = [w for w in new_words if not w in stop_words]
    filtered_words = [w for w in filtered_words if len(w) > 1]

    cleaned_desc.append(filtered_words)
  except:
    cleaned_desc.append('')
# Out:
# Number of rows read until now: 500
# Number of rows read until now: 1000
# Number of rows read until now: 1500
# Number of rows read until now: 2000
# Number of rows read until now: 2500
# Number of rows read until now: 3000
# Number of rows read until now: 3500
# Number of rows read until now: 4000
# Number of rows read until now: 4500
# Number of rows read until now: 5000
# Number of rows read until now: 5500
# Number of rows read until now: 6000
# Number of rows read until now: 6500
# Number of rows read until now: 7000
# Number of rows read until now: 7500
# Number of rows read until now: 8000
# Number of rows read until now: 8500
# Number of rows read until now: 9000
# Number of rows read until now: 9500
# Number of rows read until now: 10000
# Number of rows read until now: 10500
# Number of rows read until now: 11000
# Number of rows read until now: 11500
# Number of rows read until now: 12000
# Number of rows read until now: 12500
# Number of rows read until now: 13000
# Number of rows read until now: 13500
# Number of rows read until now: 14000
# Number of rows read until now: 14500
# Number of rows read until now: 15000
# Number of rows read until now: 15500
# Number of rows read until now: 16000
# Number of rows read until now: 16500
# Number of rows read until now: 17000
# Number of rows read until now: 17500
# Number of rows read until now: 18000
# Number of rows read until now: 18500
# Number of rows read until now: 19000
# Number of rows read until now: 19500
# Number of rows read until now: 20000
# Number of rows read until now: 20500
# Number of rows read until now: 21000
# Number of rows read until now: 21500
# Number of rows read until now: 22000
# Number of rows read until now: 22500
# Number of rows read until now: 23000
# Number of rows read until now: 23500
# Number of rows read until now: 24000
# Number of rows read until now: 24500
# Number of rows read until now: 25000
# Number of rows read until now: 25500
# Number of rows read until now: 26000
# Number of rows read until now: 26500
# Number of rows read until now: 27000
# Number of rows read until now: 27500
# Number of rows read until now: 28000
# Number of rows read until now: 28500
# Number of rows read until now: 29000
# Number of rows read until now: 29500
# Number of rows read until now: 30000
# Number of rows read until now: 30500
# Number of rows read until now: 31000
# Number of rows read until now: 31500
# Number of rows read until now: 32000
# Number of rows read until now: 32500
# Number of rows read until now: 33000
# Number of rows read until now: 33500
# Number of rows read until now: 34000
# Number of rows read until now: 34500
# Number of rows read until now: 35000
# Number of rows read until now: 35500
# Number of rows read until now: 36000
# Number of rows read until now: 36500
# Number of rows read until now: 37000
# Number of rows read until now: 37500
# Number of rows read until now: 38000
# Number of rows read until now: 38500
# Number of rows read until now: 39000
# Number of rows read until now: 39500
# Number of rows read until now: 40000
# Number of rows read until now: 40500
# Number of rows read until now: 41000
# Number of rows read until now: 41500
# Number of rows read until now: 42000
# Number of rows read until now: 42500
# Number of rows read until now: 43000
# Number of rows read until now: 43500
# Number of rows read until now: 44000
# Number of rows read until now: 44500
# Number of rows read until now: 45000
# Number of rows read until now: 45500
# Number of rows read until now: 46000
# Number of rows read until now: 46500
# Number of rows read until now: 47000
# Number of rows read until now: 47500
# Number of rows read until now: 48000
# Number of rows read until now: 48500
# Number of rows read until now: 49000
# Number of rows read until now: 49500
# Number of rows read until now: 50000
# Number of rows read until now: 50500

# %%
import string

def cleanwords(l):
  cleaned_l = []
  for w in l:
    w = w.lstrip()
    w = w.rstrip()
    w = w.lower()
    w = w.translate(str.maketrans('','',string.punctuation))
    cleaned_l.append(w)
  return cleaned_l
  



df_tweets['Cleaned'] = pd.Series(cleaned_desc)
print(df_tweets.head(5))

df_tweets['Cleaned'] = df_tweets['Cleaned'].map(cleanwords)
print(df_tweets.head(5))
# Out:
#           timestamp  ...                                            Cleaned
# 0  10/27/2019 23:59  ...  [ams, adds, laser, detection, auto-focus, sees...
# 1  10/27/2019 23:59  ...  [check, pollix, watch, prime, health, fitness,...
# 2  10/27/2019 23:49  ...  [fii, ifever, bluetooth, intelligent, thermome...
# 3  10/27/2019 23:43  ...  [stylish, pierced, look, comfortable, triangle...
# 4  10/27/2019 23:42  ...  [really, enjoyed, discussions, today, intensiv...
#
# [5 rows x 4 columns]
#           timestamp  ...                                            Cleaned
# 0  10/27/2019 23:59  ...  [ams, adds, laser, detection, autofocus, sees,...
# 1  10/27/2019 23:59  ...  [check, pollix, watch, prime, health, fitness,...
# 2  10/27/2019 23:49  ...  [fii, ifever, bluetooth, intelligent, thermome...
# 3  10/27/2019 23:43  ...  [stylish, pierced, look, comfortable, triangle...
# 4  10/27/2019 23:42  ...  [really, enjoyed, discussions, today, intensiv...
#
# [5 rows x 4 columns]

# %%
brands_list = ['google','fitbit','apple','samsung','garmin','xiaomi','motorola','fossil','sony','huawei','whoop','']

# %%
def brandlist(l):
  brands = []
  try:
    for w in l:
      if w in brands_list:
        brands.append(w)
    brands = list(set(brands))
    return brands
  except:
    return brands


df_tweets['Brandlist'] = df_tweets['Cleaned'].map(brandlist)

# %%
df_tweets.head(5)
# Out:
#           timestamp  ... Brandlist
# 0  10/27/2019 23:59  ...        []
# 1  10/27/2019 23:59  ...        []
# 2  10/27/2019 23:49  ...        []
# 3  10/27/2019 23:43  ...        []
# 4  10/27/2019 23:42  ...        []
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Adding a feature with time flags

# %%
import datetime

## Adding a flag for dates
## Before the news (till 27th Oct) - the flag is 0
## During the peak period (28th Oct - 2nd Nov) - the flag is 1
## After the peak - the flag is 2

from datetime import datetime,date

def getdate(d):
  if type(d) == str:
    dt = d.split('/')
    return datetime(int(dt[2]), int(dt[0]),int(dt[1])).date()
  else:
    return d

df_tweets['date'] = df_tweets['date'].map(getdate)



def dateflag(d):
  if type(d) == float:
    return 0
  else:

    if d >= datetime(2019,10,28).date() and d <= datetime(2019,11,2).date() :
      return 1
    elif d >= datetime(2019,11,3).date():
      return 2
    else:
      return 0

df_tweets['after_news'] = df_tweets['date'].map(dateflag)

df_tweets['after_news'].value_counts()
# Out:
# 2    19296
# 0    16930
# 1    14629
# Name: after_news, dtype: int64

# %% [markdown]
# ## **PRE PERIOD**

# %%
df_tweets_pre = df_tweets[df_tweets['after_news'] == 0]
df_tweets_pre.shape
# Out:
# (16930, 6)

# %%
## Brands by frequency of mentions

brandcounts = pd.Series(df_tweets_pre['Brandlist'].sum()).value_counts()
brandcounts.plot(kind = 'bar')
plt.xlabel('Brand Name')
plt.ylabel('Number of Mentions')
plt.title('Top 10 Brands')
# Out:
# Text(0.5, 1.0, 'Top 10 Brands')

# %%
import itertools
from itertools import product

lst = brandcounts.index.tolist()

a = []
b = []

for i in lst:
  if len(i) > 0:
    a.append(i)
    b.append(i)

combinations = pd.DataFrame(itertools.product(a, b))
combinations.columns = ["Brand1","Brand2"]
combinations.head(5)
# Out:
#   Brand1   Brand2
# 0  apple    apple
# 1  apple  samsung
# 2  apple   fitbit
# 3  apple   garmin
# 4  apple   fossil

# %%
## Getting the individual Brand Occurences

def getcounts(s):
  counts = brandcounts[s]
  return counts


combinations['Brand1_occurence'] = combinations['Brand1'].map(getcounts)
combinations['Brand2_occurence'] = combinations['Brand2'].map(getcounts)
combinations.head(5)
# Out:
#   Brand1   Brand2  Brand1_occurence  Brand2_occurence
# 0  apple    apple               990               990
# 1  apple  samsung               990               743
# 2  apple   fitbit               990               610
# 3  apple   garmin               990               359
# 4  apple   fossil               990               330

# %%
## Getting the cooccurences

def getcooccurence(s):
  brands = s.split('&')
  cntr = 0
  if brands[0] != brands[1]:
    for lst in df_tweets_pre['Brandlist'].values.tolist():
      if brands[0] in lst and brands[1] in lst:
        cntr = cntr+1
    return cntr

combinations['Brand1&Brand2'] = combinations['Brand1']+'&'+combinations['Brand2']
combinations['Cooccurence'] = combinations['Brand1&Brand2'].map(getcooccurence)
combinations.head(5)
# Out:
#   Brand1   Brand2  ...  Brand1&Brand2  Cooccurence
# 0  apple    apple  ...    apple&apple          NaN
# 1  apple  samsung  ...  apple&samsung        151.0
# 2  apple   fitbit  ...   apple&fitbit         89.0
# 3  apple   garmin  ...   apple&garmin         30.0
# 4  apple   fossil  ...   apple&fossil         26.0
#
# [5 rows x 6 columns]

# %%
## Calculating the lift

combinations['Lift'] = (df_tweets_pre.shape[0] * combinations['Cooccurence'])/(combinations['Brand1_occurence']*combinations['Brand2_occurence'])
combinations.head(5)
# Out:
#   Brand1   Brand2  Brand1_occurence  ...  Brand1&Brand2 Cooccurence      Lift
# 0  apple    apple               990  ...    apple&apple         NaN       NaN
# 1  apple  samsung               990  ...  apple&samsung       151.0  3.475441
# 2  apple   fitbit               990  ...   apple&fitbit        89.0  2.495065
# 3  apple   garmin               990  ...   apple&garmin        30.0  1.429054
# 4  apple   fossil               990  ...   apple&fossil        26.0  1.347352
#
# [5 rows x 7 columns]

# %%
combinations.sort_values(by = 'Lift',ascending=False)
# Out:
#        Brand1    Brand2  ...  Cooccurence       Lift
# 107  motorola    xiaomi  ...          2.0  39.463869
# 97     xiaomi  motorola  ...          2.0  39.463869
# 106  motorola      sony  ...          1.0  13.764228
# 86       sony  motorola  ...          1.0  13.764228
# 75     huawei  motorola  ...          1.0  13.764228
# ..        ...       ...  ...          ...        ...
# 72     huawei    huawei  ...          NaN        NaN
# 84       sony      sony  ...          NaN        NaN
# 96     xiaomi    xiaomi  ...          NaN        NaN
# 108  motorola  motorola  ...          NaN        NaN
# 120     whoop     whoop  ...          NaN        NaN
#
# [121 rows x 7 columns]

# %%
## Getting in Matrix Format for Lifts

brands = list(combinations['Brand1'].unique())
df_lifts = pd.DataFrame(index=brands, columns=brands)
for i in brands:
  for j in brands:
    x = combinations[combinations['Brand1'] == i]
    value = x[x['Brand2'] == j]['Lift'].values[0]
    df_lifts[i].loc[j] = value
 
df_lifts.iloc[:10,:10]
# Out:
#              apple  samsung    fitbit  ...      sony   xiaomi motorola
# apple          NaN  3.47544   2.49507  ...  0.583937  3.10927  2.85017
# samsung    3.47544      NaN   1.75564  ...   2.11187  3.98357  3.79767
# fitbit     2.49507  1.75564       NaN  ...  0.812315  3.29944        0
# garmin     1.42905   4.1256   3.09238  ...  0.230043  4.61694        0
# fossil     1.34735  1.38097   1.26155  ...         0  1.07629  8.55051
# google      2.3426  3.12137    1.6475  ...   1.13131  3.78421        0
# huawei     1.33471  2.66763  0.270772  ...   2.01428  6.35272  13.7642
# sony      0.583937  2.11187  0.812315  ...       NaN  1.15504  13.7642
# xiaomi     3.10927  3.98357   3.29944  ...   1.15504      NaN  39.4639
# motorola   2.85017  3.79767         0  ...   13.7642  39.4639      NaN
#
# [10 rows x 10 columns]

# %%
## Getting in Matrix Format for MDS


brands = list(combinations['Brand1'].unique())
df = pd.DataFrame(index=brands, columns=brands)
for i in brands:
  for j in brands:
    x = combinations[combinations['Brand1'] == i]
    value = 1/(x[x['Brand2'] == j]['Lift'].values[0])
    if value == float("inf"):
      value = 0
    elif np.isnan(value):
      value = 0
    df[i].loc[j] = value
 
df.iloc[:10,:10]
# Out:
#              apple   samsung    fitbit  ...       sony     xiaomi   motorola
# apple            0  0.287733  0.400791  ...    1.71251   0.321618   0.350856
# samsung   0.287733         0  0.569592  ...   0.473513   0.251031    0.26332
# fitbit    0.400791  0.569592         0  ...    1.23105   0.303082          0
# garmin    0.699764  0.242389  0.323376  ...    4.34702   0.216594          0
# fossil    0.742196  0.724129  0.792676  ...          0    0.92912   0.116952
# google    0.426875  0.320372  0.606979  ...   0.883934   0.264256          0
# huawei    0.749225  0.374865   3.69315  ...   0.496456   0.157413  0.0726521
# sony       1.71251  0.473513   1.23105  ...          0   0.865771  0.0726521
# xiaomi    0.321618  0.251031  0.303082  ...   0.865771          0  0.0253396
# motorola  0.350856   0.26332         0  ...  0.0726521  0.0253396          0
#
# [10 rows x 10 columns]

# %%
#https://datascience.stackexchange.com/questions/49316/multidimensional-scaling-producing-different-results-for-different-seeds

from sklearn import manifold

df_new = df.iloc[:10,:10]

#df_new = df
mds = manifold.MDS(n_components=2, dissimilarity="precomputed", random_state=6)
results = mds.fit(df_new.values)

brands = df_new.columns
coords = results.embedding_

fig = plt.figure(figsize=(5,5))

plt.subplots_adjust(bottom = 0.1)
plt.scatter(coords[:, 0], coords[:, 1])

# for label, x, y in zip(brands, coords[:, 0], coords[:, 1]):
#     plt.annotate(
#         label,
#         xy = (x, y), 
#         xytext = (-20, 20),
#         textcoords = 'offset points'
#     )

for label, x, y in zip(brands, coords[:, 0], coords[:, 1]):
    plt.annotate(
        label,
        xy = (x, y), xytext = (-20, 20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))
    
plt.show()

# %% [markdown]
# ## **DURING PEAK**

# %%
df_tweets_peak = df_tweets[df_tweets['after_news'] == 1]
df_tweets_peak.shape
# Out:
# (14629, 6)

# %%
## Brands by frequency of mentions

brandcounts = pd.Series(df_tweets_peak['Brandlist'].sum()).value_counts()
brandcounts.plot(kind = 'bar')
plt.xlabel('Brand Name')
plt.ylabel('Number of Mentions')
plt.title('Top 10 Brands')
# Out:
# Text(0.5, 1.0, 'Top 10 Brands')

# %%
import itertools
from itertools import product

lst = brandcounts.index.tolist()

a = []
b = []

for i in lst:
  if len(i) > 0:
    a.append(i)
    b.append(i)

combinations = pd.DataFrame(itertools.product(a, b))
combinations.columns = ["Brand1","Brand2"]
combinations.head(5)
# Out:
#    Brand1   Brand2
# 0  fitbit   fitbit
# 1  fitbit   google
# 2  fitbit    apple
# 3  fitbit   xiaomi
# 4  fitbit  samsung

# %%
## Getting the individual Brand Occurences

def getcounts(s):
  counts = brandcounts[s]
  return counts


combinations['Brand1_occurence'] = combinations['Brand1'].map(getcounts)
combinations['Brand2_occurence'] = combinations['Brand2'].map(getcounts)
combinations.head(5)
# Out:
#    Brand1   Brand2  Brand1_occurence  Brand2_occurence
# 0  fitbit   fitbit              4279              4279
# 1  fitbit   google              4279              4183
# 2  fitbit    apple              4279              2357
# 3  fitbit   xiaomi              4279               782
# 4  fitbit  samsung              4279               376

# %%
## Getting the cooccurences

def getcooccurence(s):
  brands = s.split('&')
  cntr = 0
  if brands[0] != brands[1]:
    for lst in df_tweets_peak['Brandlist'].values.tolist():
      if brands[0] in lst and brands[1] in lst:
        cntr = cntr+1
    return cntr

combinations['Brand1&Brand2'] = combinations['Brand1']+'&'+combinations['Brand2']
combinations['Cooccurence'] = combinations['Brand1&Brand2'].map(getcooccurence)
combinations.head(5)
# Out:
#    Brand1   Brand2  ...   Brand1&Brand2  Cooccurence
# 0  fitbit   fitbit  ...   fitbit&fitbit          NaN
# 1  fitbit   google  ...   fitbit&google       3735.0
# 2  fitbit    apple  ...    fitbit&apple        605.0
# 3  fitbit   xiaomi  ...   fitbit&xiaomi         10.0
# 4  fitbit  samsung  ...  fitbit&samsung         57.0
#
# [5 rows x 6 columns]

# %%
## Calculating the lift

combinations['Lift'] = (df_tweets_peak.shape[0] * combinations['Cooccurence'])/(combinations['Brand1_occurence']*combinations['Brand2_occurence'])
combinations.head(5)
# Out:
#    Brand1   Brand2  Brand1_occurence  ...   Brand1&Brand2 Cooccurence      Lift
# 0  fitbit   fitbit              4279  ...   fitbit&fitbit         NaN       NaN
# 1  fitbit   google              4279  ...   fitbit&google      3735.0  3.052637
# 2  fitbit    apple              4279  ...    fitbit&apple       605.0  0.877542
# 3  fitbit   xiaomi              4279  ...   fitbit&xiaomi        10.0  0.043719
# 4  fitbit  samsung              4279  ...  fitbit&samsung        57.0  0.518274
#
# [5 rows x 7 columns]

# %%
combinations.sort_values(by = 'Lift',ascending=False)
# Out:
#       Brand1   Brand2  Brand1_occurence  ...   Brand1&Brand2 Cooccurence       Lift
# 53   samsung     sony               376  ...    samsung&sony        10.0  10.515382
# 103     sony  samsung                37  ...    sony&samsung        10.0  10.515382
# 97    huawei     sony                95  ...     huawei&sony         2.0   8.323755
# 107     sony   huawei                37  ...     sony&huawei         2.0   8.323755
# 92    huawei  samsung                95  ...  huawei&samsung        17.0   6.962290
# ..       ...      ...               ...  ...             ...         ...        ...
# 72    garmin   garmin               156  ...   garmin&garmin         NaN        NaN
# 84    fossil   fossil               131  ...   fossil&fossil         NaN        NaN
# 96    huawei   huawei                95  ...   huawei&huawei         NaN        NaN
# 108     sony     sony                37  ...       sony&sony         NaN        NaN
# 120    whoop    whoop                 1  ...     whoop&whoop         NaN        NaN
#
# [121 rows x 7 columns]

# %%
## Getting in Matrix Format for Lifts

brands = list(combinations['Brand1'].unique())
df_lifts = pd.DataFrame(index=brands, columns=brands)
for i in brands:
  for j in brands:
    x = combinations[combinations['Brand1'] == i]
    value = x[x['Brand2'] == j]['Lift'].values[0]
    df_lifts[i].loc[j] = value
 
df_lifts.iloc[:10,:10]
# Out:
#              fitbit     google      apple  ...    fossil    huawei       sony
# fitbit          NaN    3.05264   0.877542  ...   1.38317  0.251911   0.184799
# google      3.05264        NaN    0.90065  ...   1.22804  0.257692  0.0945203
# apple      0.877542    0.90065        NaN  ...  0.947575   1.30666    1.34197
# xiaomi    0.0437185  0.0491941    3.69857  ...         0   1.96917     1.5168
# samsung    0.518274   0.613879    2.03036  ...     1.188   6.96229    10.5154
# motorola  0.0773482   0.110773  0.0561685  ...  0.505302  0.696785    1.78904
# garmin      0.70129   0.224183   0.915078  ...   5.01091   2.96134    5.06895
# fossil      1.38317    1.22804   0.947575  ...       NaN   4.70197    6.03631
# huawei     0.251911   0.257692    1.30666  ...   4.70197       NaN    8.32376
# sony       0.184799  0.0945203    1.34197  ...   6.03631   8.32376        NaN
#
# [10 rows x 10 columns]

# %%
## Getting in Matrix Format for MDS


brands = list(combinations['Brand1'].unique())
df = pd.DataFrame(index=brands, columns=brands)
for i in brands:
  for j in brands:
    x = combinations[combinations['Brand1'] == i]
    value = 1/(x[x['Brand2'] == j]['Lift'].values[0])
    if value == float("inf"):
      value = 0
    elif np.isnan(value):
      value = 0
    df[i].loc[j] = value
 
df.iloc[:10,:10]
# Out:
#             fitbit    google     apple  ...    fossil    huawei       sony
# fitbit           0  0.327586   1.13955  ...  0.722975   3.96966    5.41127
# google    0.327586         0   1.11031  ...  0.814304    3.8806    10.5797
# apple      1.13955   1.11031         0  ...   1.05533  0.765312   0.745172
# xiaomi     22.8736   20.3277  0.270375  ...         0  0.507827   0.659284
# samsung    1.92948   1.62899  0.492524  ...  0.841753  0.143631  0.0950988
# motorola   12.9286    9.0275   17.8036  ...   1.97901   1.43516   0.558958
# garmin     1.42594   4.46065    1.0928  ...  0.199564  0.337685   0.197279
# fossil    0.722975  0.814304   1.05533  ...         0  0.212677   0.165664
# huawei     3.96966    3.8806  0.765312  ...  0.212677         0   0.120138
# sony       5.41127   10.5797  0.745172  ...  0.165664  0.120138          0
#
# [10 rows x 10 columns]

# %%
#https://datascience.stackexchange.com/questions/49316/multidimensional-scaling-producing-different-results-for-different-seeds

from sklearn import manifold

df_new = df.iloc[:10,:10]

#df_new = df
mds = manifold.MDS(n_components=2, dissimilarity="precomputed", random_state=6)
results = mds.fit(df_new.values)

brands = df_new.columns
coords = results.embedding_

fig = plt.figure(figsize=(5,5))

plt.subplots_adjust(bottom = 0.1)
plt.scatter(coords[:, 0], coords[:, 1])

for label, x, y in zip(brands, coords[:, 0], coords[:, 1]):
    plt.annotate(
        label,
        xy = (x, y), 
        xytext = (-20, 20),
        textcoords = 'offset points'
    )
plt.show()

# %% [markdown]
# ## **After PEAK**

# %%
df_tweets_after = df_tweets[df_tweets['after_news'] == 2]
df_tweets_after.shape
# Out:
# (19296, 6)

# %%
## Brands by frequency of mentions

brandcounts = pd.Series(df_tweets_after['Brandlist'].sum()).value_counts()
brandcounts.plot(kind = 'bar')
plt.xlabel('Brand Name')
plt.ylabel('Number of Mentions')
plt.title('Top 10 Brands')
# Out:
# Text(0.5, 1.0, 'Top 10 Brands')

# %%
import itertools
from itertools import product

lst = brandcounts.index.tolist()

a = []
b = []

for i in lst:
  if len(i) > 0:
    a.append(i)
    b.append(i)

combinations = pd.DataFrame(itertools.product(a, b))
combinations.columns = ["Brand1","Brand2"]
combinations.head(5)
# Out:
#    Brand1   Brand2
# 0  fitbit   fitbit
# 1  fitbit    apple
# 2  fitbit   google
# 3  fitbit  samsung
# 4  fitbit   fossil

# %%
## Getting the individual Brand Occurences

def getcounts(s):
  counts = brandcounts[s]
  return counts


combinations['Brand1_occurence'] = combinations['Brand1'].map(getcounts)
combinations['Brand2_occurence'] = combinations['Brand2'].map(getcounts)
combinations.head(5)
# Out:
#    Brand1   Brand2  Brand1_occurence  Brand2_occurence
# 0  fitbit   fitbit              1853              1853
# 1  fitbit    apple              1853              1726
# 2  fitbit   google              1853              1607
# 3  fitbit  samsung              1853               844
# 4  fitbit   fossil              1853               667

# %%
## Getting the cooccurences

def getcooccurence(s):
  brands = s.split('&')
  cntr = 0
  if brands[0] != brands[1]:
    for lst in df_tweets_after['Brandlist'].values.tolist():
      if brands[0] in lst and brands[1] in lst:
        cntr = cntr+1
    return cntr

combinations['Brand1&Brand2'] = combinations['Brand1']+'&'+combinations['Brand2']
combinations['Cooccurence'] = combinations['Brand1&Brand2'].map(getcooccurence)
combinations.head(5)
# Out:
#    Brand1   Brand2  ...   Brand1&Brand2  Cooccurence
# 0  fitbit   fitbit  ...   fitbit&fitbit          NaN
# 1  fitbit    apple  ...    fitbit&apple        243.0
# 2  fitbit   google  ...   fitbit&google       1258.0
# 3  fitbit  samsung  ...  fitbit&samsung         57.0
# 4  fitbit   fossil  ...   fitbit&fossil         22.0
#
# [5 rows x 6 columns]

# %%
## Calculating the lift

combinations['Lift'] = (df_tweets_after.shape[0] * combinations['Cooccurence'])/(combinations['Brand1_occurence']*combinations['Brand2_occurence'])
combinations.head(5)
# Out:
#    Brand1   Brand2  Brand1_occurence  ...   Brand1&Brand2 Cooccurence      Lift
# 0  fitbit   fitbit              1853  ...   fitbit&fitbit         NaN       NaN
# 1  fitbit    apple              1853  ...    fitbit&apple       243.0  1.466079
# 2  fitbit   google              1853  ...   fitbit&google      1258.0  8.151859
# 3  fitbit  samsung              1853  ...  fitbit&samsung        57.0  0.703274
# 4  fitbit   fossil              1853  ...   fitbit&fossil        22.0  0.343470
#
# [5 rows x 7 columns]

# %%
combinations.sort_values(by = 'Lift',ascending=False)
# Out:
#        Brand1    Brand2  ...  Cooccurence       Lift
# 119      sony  motorola  ...          4.0  12.199147
# 109  motorola      sony  ...          4.0  12.199147
# 113      sony   samsung  ...         30.0  12.032926
# 43    samsung      sony  ...         30.0  12.032926
# 118      sony    huawei  ...          5.0   9.300174
# ..        ...       ...  ...          ...        ...
# 72     garmin    garmin  ...          NaN        NaN
# 84      whoop     whoop  ...          NaN        NaN
# 96     huawei    huawei  ...          NaN        NaN
# 108  motorola  motorola  ...          NaN        NaN
# 120      sony      sony  ...          NaN        NaN
#
# [121 rows x 7 columns]

# %%
## Getting in Matrix Format for Lifts

brands = list(combinations['Brand1'].unique())
df_lifts = pd.DataFrame(index=brands, columns=brands)
for i in brands:
  for j in brands:
    x = combinations[combinations['Brand1'] == i]
    value = x[x['Brand2'] == j]['Lift'].values[0]
    df_lifts[i].loc[j] = value
 
df_lifts.iloc[:10,:10]
# Out:
#             fitbit     apple    google  ...     whoop    huawei  motorola
# fitbit         NaN   1.46608   8.15186  ...  0.348565  0.514948  0.281443
# apple      1.46608       NaN   1.59311  ...  0.935532   2.02707  0.402869
# google     8.15186   1.59311       NaN  ...   1.35649  0.527801  0.216351
# samsung   0.703274   2.58297  0.426806  ...         0   5.27598   1.64775
# fossil     0.34347  0.284937  0.522064  ...         0  0.317907         0
# xiaomi    0.302129   3.11386  0.487731  ...         0     2.871   1.34497
# garmin    0.593839  0.705841  0.171186  ...         0  0.215931         0
# whoop     0.348565  0.935532   1.35649  ...       NaN         0         0
# huawei    0.514948   2.02707  0.527801  ...         0       NaN   3.82061
# motorola  0.281443  0.402869  0.216351  ...         0   3.82061       NaN
#
# [10 rows x 10 columns]

# %%
## Getting in Matrix Format for MDS


brands = list(combinations['Brand1'].unique())
df = pd.DataFrame(index=brands, columns=brands)
for i in brands:
  for j in brands:
    x = combinations[combinations['Brand1'] == i]
    value = 1/(x[x['Brand2'] == j]['Lift'].values[0])
    if value == float("inf"):
      value = 0
    elif np.isnan(value):
      value = 0
    df[i].loc[j] = value
 
df.iloc[:10,:10]
# Out:
#             fitbit     apple    google  ...     whoop    huawei  motorola
# fitbit           0  0.682092  0.122671  ...    2.8689   1.94195   3.55312
# apple     0.682092         0  0.627703  ...   1.06891  0.493323    2.4822
# google    0.122671  0.627703         0  ...  0.737196   1.89465   4.62212
# samsung    1.42192  0.387152   2.34299  ...         0  0.189538  0.606887
# fossil     2.91146   3.50954   1.91547  ...         0   3.14557         0
# xiaomi     3.30984  0.321145   2.05031  ...         0  0.348311  0.743509
# garmin     1.68396   1.41675    5.8416  ...         0   4.63112         0
# whoop       2.8689   1.06891  0.737196  ...         0         0         0
# huawei     1.94195  0.493323   1.89465  ...         0         0  0.261738
# motorola   3.55312    2.4822   4.62212  ...         0  0.261738         0
#
# [10 rows x 10 columns]

# %%
#https://datascience.stackexchange.com/questions/49316/multidimensional-scaling-producing-different-results-for-different-seeds

from sklearn import manifold

df_new = df.iloc[:10,:10]

#df_new = df
mds = manifold.MDS(n_components=2, dissimilarity="precomputed", random_state=6)
results = mds.fit(df_new.values)

brands = df_new.columns
coords = results.embedding_

fig = plt.figure(figsize=(5,5))

plt.subplots_adjust(bottom = 0.1)
plt.scatter(coords[:, 0], coords[:, 1])

for label, x, y in zip(brands, coords[:, 0], coords[:, 1]):
    plt.annotate(
        label,
        xy = (x, y), 
        xytext = (-20, 20),
        textcoords = 'offset points'
    )
plt.show()
