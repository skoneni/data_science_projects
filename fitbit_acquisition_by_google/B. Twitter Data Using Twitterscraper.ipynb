# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount= True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#https://github.com/taspinar/twitterscraper

pip install twitterscraper
# Out:
# ...
#      |████████████████████████████████| 92kB 7.2MB/s
# ...
#   Created wheel for twitterscraper: filename=twitterscraper-1.4.0-cp36-none-any.whl size=11347 sha256=8c02ed24047f10f78ae0843a3ae35e80f2136f26448efbe1fd1a599d6236622a
#   Stored in directory: /root/.cache/pip/wheels/c2/9c/8b/7393e7bdc8abe6ce0d46c2ffae2035a1a2080a97ff0ddbdde6
# Successfully built twitterscraper
# ...

# %%
# !twitterscraper Fitbit -bd 2019-10-15 -ed 2019-11-15 -o tweets.json
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows NT 5.2; RW; rv:7.0a1) Gecko/20091211 SeaMonkey/9.23a1pre'}
# ...

# %%
import pandas as pd
df_tweets = pd.read_json('tweets.json', encoding='utf-8')

# %%
df_tweets.head(4)
# Out:
#    has_media               hashtags  ...          username  video_url
# 0      False  [fitness, sportgears]  ...          Kamzou L
# 1      False                     []  ...  Socrates Johnson
# 2      False                     []  ...     Erin Roberts🧸
# 3      False    [fitbit, googlefit]  ...        StepEscape
#
# [4 rows x 21 columns]

# %%
df_tweets['timestamp'] = pd.to_datetime(df_tweets['timestamp'],unit='s')

# %%
df_tweets['date'] = df_tweets['timestamp'].dt.date

# %%
df_tweets['date'][0]
# Out:
# datetime.date(2019, 10, 27)

# %%
df_tweets.to_csv("/content/gdrive/My Drive/Colab Notebooks/Text Analytics/Project/All_tweets_data.csv")

# %%
df_tweets.columns
# Out:
# Index(['has_media', 'hashtags', 'img_urls', 'is_replied', 'is_reply_to',
#        'likes', 'links', 'parent_tweet_id', 'replies', 'reply_to_users',
#        'retweets', 'screen_name', 'text', 'text_html', 'timestamp',
#        'timestamp_epochs', 'tweet_id', 'tweet_url', 'user_id', 'username',
#        'video_url', 'date'],
#       dtype='object')
